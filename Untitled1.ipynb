# %%
import pandas as pd
import numpy as np
# Out:
# D:\DProgramFiles\Anaconda3\envs\KM-Trading\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# D:\DProgramFiles\Anaconda3\envs\KM-Trading\lib\site-packages\numpy\.libs\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll
# D:\DProgramFiles\Anaconda3\envs\KM-Trading\lib\site-packages\numpy\.libs\libopenblas.XWYDX2IKJW2NMTWSFYNGFUWKQU3LYTCZ.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
dataFile = 'addedFeaturesToNormalized_USD_JPY_2021-01-01_to_2021-12-31_M1_A' + '.pkl'
dataFile2 = 'normalized_USD_JPY_2021-01-01_to_2021-12-31_M1_A' + '.pkl'

# %%
dataFile2
# Out:
# 'normalized_USD_JPY_2021-01-01_to_2021-12-31_M1_A.pkl'

# %%
df = pd.read_pickle(dataFile2)

# %%
df.head()
# Out:
#                             o         h         l         c    volume  \
# time
# 2021-01-03 23:01:00  0.051387  0.050929  0.049713  0.049543  0.380089
# 2021-01-03 23:02:00  0.049915  0.049458  0.050178  0.049775  0.197904
# 2021-01-03 23:03:00  0.049760  0.050542  0.050101  0.050628  0.380089
# 2021-01-03 23:04:00  0.050690  0.050387  0.050644  0.050085  0.374369
# 2021-01-03 23:05:00  0.049992  0.050387  0.050489  0.050318  0.324511
#
#                             r       sma       min       max           mom  \
# time
# 2021-01-03 23:01:00 -0.035361  0.051620  0.049543  0.054117 -1.160145e-03
# 2021-01-03 23:02:00  0.004684  0.051605  0.049543  0.054117 -3.105600e-04
# 2021-01-03 23:03:00  0.016989  0.051605  0.049543  0.054117  1.387779e-17
# 2021-01-03 23:04:00 -0.010778  0.051609  0.049543  0.054117  7.745935e-05
# 2021-01-03 23:05:00  0.004633  0.051589  0.049543  0.054117 -3.837317e-04
#
#                      ...  std_lag_1  std_lag_2  std_lag_3  std_lag_4  \
# ...

# %%
def cw():
    c0, c1 = np.bincount(df['d'])
    print('c0: ', c0)
    print('c1: ', c1)
    w0 = (1 / c0) * (len(df))/ 2
    w1 = (1 / c1) * (len(df))/ 2
    print('w0 ', w0)
    print('w1 ', w1)
    # df.loc[df['d'] == 1, 'd'] *= w1
    # df.loc[df['d'] == 0, 'd'] += w0
    return{'0': w0, '1': w1}
    # Print the Dataframe

# %%
class_weight = cw()
# Out:
# c0:  193938
# c1:  167657
# w0  0.9322438098773834
# w1  1.0783772821892317

# %%
df['d'].head(10)
# Out:
# time
# 2021-01-03 23:01:00    0.932244
# 2021-01-03 23:02:00    1.078377
# 2021-01-03 23:03:00    1.078377
# 2021-01-03 23:04:00    0.932244
# 2021-01-03 23:05:00    1.078377
# 2021-01-03 23:06:00    1.078377
# 2021-01-03 23:07:00    0.932244
# 2021-01-03 23:08:00    1.078377
# 2021-01-03 23:09:00    0.932244
# 2021-01-03 23:10:00    1.078377
# Name: d, dtype: float64

# %%
cw()
# Out:
# c0:  193938
# c1:  167657
# w0  0.9322438098773834
# w1  1.0783772821892317

# %%
count = np.count_nonzero(df['d'] == 1)
count
# Out:
# 167657

# %%
df['d'] = np.where(df['d'] == '0',
                   df['columnname'] * 1000,
                   df['columnname'])

# %%
for col in df.columns:
    print(col)
# Out:
# o
# h
# l
# c
# volume
# r
# sma
# min
# max
# mom
# std
# d
# o_lag_1
# o_lag_2
# o_lag_3
# o_lag_4
# o_lag_5
# h_lag_1
# h_lag_2
# h_lag_3
# h_lag_4
# h_lag_5
# l_lag_1
# l_lag_2
# l_lag_3
# l_lag_4
# l_lag_5
# c_lag_1
# c_lag_2
# c_lag_3
# c_lag_4
# c_lag_5
# volume_lag_1
# volume_lag_2
# volume_lag_3
# volume_lag_4
# volume_lag_5
# r_lag_1
# r_lag_2
# r_lag_3
# r_lag_4
# r_lag_5
# sma_lag_1
# sma_lag_2
# sma_lag_3
# sma_lag_4
# sma_lag_5
# min_lag_1
# min_lag_2
# min_lag_3
# min_lag_4
# min_lag_5
# max_lag_1
# max_lag_2
# max_lag_3
# max_lag_4
# max_lag_5
# mom_lag_1
# mom_lag_2
# mom_lag_3
# mom_lag_4
# mom_lag_5
# std_lag_1
# std_lag_2
# std_lag_3
# std_lag_4
# std_lag_5
# d_lag_1
# d_lag_2
# d_lag_3
# d_lag_4
# d_lag_5

# %%
pd.set_option('display.max_rows', 20)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 1000)
pd.set_option('display.colheader_justify', 'center')
pd.set_option('display.precision', 3)
display(df)
# Out:
#                        o      h      l      c    volume      r       sma    min    max      mom        std     d  o_lag_1  o_lag_2  o_lag_3  o_lag_4  o_lag_5  h_lag_1  h_lag_2  h_lag_3  h_lag_4  h_lag_5  l_lag_1  l_lag_2  l_lag_3  l_lag_4  l_lag_5  c_lag_1  c_lag_2  c_lag_3  c_lag_4  c_lag_5  volume_lag_1  volume_lag_2  volume_lag_3  volume_lag_4  volume_lag_5   r_lag_1    r_lag_2    r_lag_3    r_lag_4    r_lag_5   sma_lag_1  sma_lag_2  sma_lag_3  sma_lag_4  sma_lag_5  min_lag_1  min_lag_2  min_lag_3  min_lag_4  min_lag_5  max_lag_1  max_lag_2  max_lag_3  max_lag_4  max_lag_5  mom_lag_1  mom_lag_2  mom_lag_3  mom_lag_4  mom_lag_5  std_lag_1  std_lag_2  std_lag_3  std_lag_4  std_lag_5  d_lag_1  d_lag_2  d_lag_3  d_lag_4  d_lag_5
# time
# ...

# %%
df.corr()
# Out:
#            o      h      l      c    volume      r       sma    min    max    mom    std     d    o_lag_1  o_lag_2  o_lag_3  o_lag_4  o_lag_5  h_lag_1  h_lag_2  h_lag_3  h_lag_4  h_lag_5  l_lag_1  l_lag_2  l_lag_3  l_lag_4  l_lag_5  c_lag_1  c_lag_2  c_lag_3  c_lag_4  c_lag_5  volume_lag_1  volume_lag_2  volume_lag_3  volume_lag_4  volume_lag_5   r_lag_1    r_lag_2    r_lag_3    r_lag_4    r_lag_5   sma_lag_1  sma_lag_2  sma_lag_3  sma_lag_4  sma_lag_5  min_lag_1  min_lag_2  min_lag_3  min_lag_4  min_lag_5  max_lag_1  max_lag_2  max_lag_3  max_lag_4  max_lag_5  mom_lag_1  mom_lag_2  mom_lag_3  mom_lag_4  mom_lag_5  std_lag_1  std_lag_2  std_lag_3  std_lag_4  std_lag_5  d_lag_1  d_lag_2  d_lag_3  d_lag_4  d_lag_5
# ...

# %%
print('Rows: %d' % df.shape[0])
print('Cols: %d' % df.shape[1])
# Out:
# Rows: 361595
# Cols: 72
